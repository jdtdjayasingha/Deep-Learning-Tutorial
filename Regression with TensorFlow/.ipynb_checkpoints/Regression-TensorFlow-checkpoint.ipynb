# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import opendatasets as od
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Preprocessing

# %%
od.download("https://www.kaggle.com/datasets/andonians/random-linear-regression")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:  jdtdjayasingha
# Your Kaggle Key:  ········
# Dataset URL: https://www.kaggle.com/datasets/andonians/random-linear-regression
# Downloading random-linear-regression.zip to ./random-linear-regression
# 100%|██████████████████████████████████████████████████████████████████████████| 7.63k/7.63k [00:00<00:00, 6.91MB/s]

# %%
data = pd.read_csv("random-linear-regression/test.csv")

# %%
data.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
data.tail()
# Out:
#       x          y
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467

# %%
data.shape
# Out:
# (300, 2)

# %%
x = data['x']
y = data['y']

# %%
plt.scatter(x, y , c='b')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((240,), (60,))

# %%
plt.scatter(X_train, y_train, c='b', label='Training data')
plt.scatter(X_test, y_test, c='y', label='Testing data')
plt.legend()
plt.show()

# %% [markdown]
# # Model Building

# %% [markdown]
# ### Create a model

# %%
model = tf.keras.Sequential ([
        tf.keras.layers.Dense (4, input_shape = (1,)),
        tf.keras.layers.Dense (1)
    ])

# %% [markdown]
# ### Compile model

# %%
model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ['mae'])

# %% [markdown]
# ### Train model

# %%
epoch_number = 4

# %%
model.fit(tf.expand_dims(x_train, axis = 1), y_train, epochs = epoch_number)
# Out:
# Epoch 1/4
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.2081 - mae: 32.2081
# Epoch 2/4
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5492 - mae: 20.5492
# Epoch 3/4
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.4675 - mae: 24.4675
# Epoch 4/4
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24.6419 - mae: 24.6419
